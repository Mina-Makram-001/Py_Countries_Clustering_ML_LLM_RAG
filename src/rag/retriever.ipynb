# %%
from langchain_chroma import Chroma
from langchain_community.embeddings import FastEmbedEmbeddings

# 1. Load the existing vector store from disk
embedding_model = FastEmbedEmbeddings()

vectorstore = Chroma(
    persist_directory="../vectorstore_db",
    embedding_function=embedding_model
)

# 2. Create the retriever interface (top 4 relevant chunks)
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 4}
)

# 3. Test Retrieval
query = "What is the economic profile of Egypt and what cluster does it belong to?"
results = retriever.invoke(query)

# Print retrieved chunks
for i, doc in enumerate(results, 1):
    print(f"--- Result {i} ---")
    print(f"Metadata: {doc.metadata}")
    print(f"Content:\n{doc.page_content[:300]}...\n")
# Out:
# C:\Users\minam\AppData\Local\Temp\ipykernel_28748\2294824637.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.embeddings import FastEmbedEmbeddings
# --- Result 1 ---
# Metadata: {'country_name': 'Egypt, Arab Rep.', 'country_code': 'EGY', 'cluster': 'Cluster_1', 'doc_type': 'country_profile', 'centroid_distance': 1.2939298562819856}
# Content:
# Country Profile: Egypt, Arab Rep. (EGY)
# Assigned Cluster: Cluster_1
# Distance to Cluster Centroid: 1.2939
# PCA Coordinates: [PC1: -0.6328, PC2: 2.0816]...
#
# --- Result 2 ---
# Metadata: {'country_count': 39, 'cluster_id': 'Cluster_1', 'doc_type': 'cluster_summary', 'cluster_name': 'Cluster 1: High-Growth Emerging Market Economies'}
# Content:
# Cluster Summary Profile: Cluster 1: High-Growth Emerging Market Economies
# Cluster ID: Cluster_1
# Size: 39 Countries (21.4% of global dataset)
#
# Member Countries:
# Algeria, Azerbaijan, Bahrain, Belarus, Bolivia, Botswana, Brunei Darussalam, China, Egypt, Arab Rep., Equatorial Guinea, Indonesia, Iran, Is...
#
# --- Result 3 ---
# Metadata: {'country_count': 80, 'cluster_id': 'Cluster_2', 'doc_type': 'cluster_summary', 'cluster_name': 'Cluster 2: Advanced High-Income & Service-Driven Economies'}
# Content:
# Cluster Summary Profile: Cluster 2: Advanced High-Income & Service-Driven Economies
# Cluster ID: Cluster_2
# Size: 80 Countries (44.0% of global dataset)...
#
# --- Result 4 ---
# Metadata: {'cluster_id': 'Cluster_3', 'cluster_name': 'Cluster 3: Low-Income Agriculture & Resource Dependent Nations', 'country_count': 63, 'doc_type': 'cluster_summary'}
# Content:
# Cluster Summary Profile: Cluster 3: Low-Income Agriculture & Resource Dependent Nations
# Cluster ID: Cluster_3
# Size: 63 Countries (34.6% of global dataset)
#
# Member Countries:
# Afghanistan, Angola, Bangladesh, Benin, Bhutan, Burkina Faso, Burundi, Cambodia, Cameroon, Central African Republic, Chad, Com...
