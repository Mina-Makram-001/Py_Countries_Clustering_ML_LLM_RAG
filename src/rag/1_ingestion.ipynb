# %% [markdown]
# ## **Data ingestion**

# %%
from langchain_core.documents import Document

# %%
# Stage 1

# 1- Document and load using langchain (from langchain_core.documents import Document) 
# 2- Chunking (from langchain.text_splitter import RecursiveCharacterTextSplitter)

# %%
# Stage 2

# 1- embedding using (
#     import numpy as np
#     from sentence_transformers import SentenceTransformer
#     import chromadb
#     from chromadb.config import Settings
#     import uuid
#     from typing import List, Dict, Any, Tuple
#     from sklearn.metrics.pairwise import cosine_similarity
# )

# 2- vector store in vector DB

# %%
# stage 3

# 1- vector store 
# 2- retrever
